# %%
import json
import asyncio
import jmespath
from httpx import AsyncClient, Response
from parsel import Selector
from typing import List, Dict
import random
import time
import requests

# %%
client = AsyncClient(
    # enable http2
    http2=True,
    # add basic browser headers to mimize blocking chancesd
    headers={
        "accept-language": "en-US,en;q=0.9",
        "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.110 Safari/537.36",
        "accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8",
        "accept-language": "en-US;en;q=0.9",
        "accept-encoding": "gzip, deflate, br",
    }
)


def parse_property_page(data: Dict) -> Dict:
    if not data:
        return
    result = jmespath.search(
        """{
    listingId: listingId,
    listingUrl: listingUrl,
    unitNumber: unitNumber,
    streetNumber: streetNumber,
    street: street,
    suburb: suburb,
    postcode: postcode,
    createdOn: createdOn,
    propertyType: propertyType,
    beds: beds,
    phone: phone,
    agencyName: agencyName,
    propertyDeveloperName: propertyDeveloperName,
    agencyProfileUrl: agencyProfileUrl,
    propertyDeveloperUrl: propertyDeveloperUrl,
    description: description,
    loanfinder: loanfinder,
    schools: schoolCatchment.schools,
    suburbInsights: suburbInsights,
    gallery: gallery,
    listingSummary: listingSummary,
    agents: agents,
    features: features,
    structuredFeatures: structuredFeatures,
    faqs: faqs
    }""",
        data,
    )
    return result

def parse_hidden_data(response: Response):
    """parse json data from script tags"""
    selector = Selector(response.text)
    script = selector.xpath("//script[@id='__NEXT_DATA__']/text()").get()
    data = json.loads(script)
    return data["props"]["pageProps"]["componentProps"]


async def scrape_properties(urls: List[str]) -> List[Dict]:
    to_scrape = [client.get(url) for url in urls]
    properties = []
    for response in asyncio.as_completed(to_scrape):
        response = await response
        if response.status_code != 200:
            print(f"Request blocked with status code {response.status_code}. Retrying...")
            continue
        data = parse_hidden_data(response)
        data = parse_property_page(data)
        properties.append(data)
        # Introduce a random delay between requests to avoid blocking
        time.sleep(random.uniform(1, 3))
    print(f"scraped {len(properties)} property listings")
    return properties 

async def run():
    data = await scrape_properties(
        urls = [
            "https://www.domain.com.au/906-238-flinders-street-melbourne-vic-3000-14781843"
        ]
    )
    print(json.dumps(data, indent=2))

await run()
# Out:
# scraped 1 property listings
# [
#   {
#     "listingId": 14781843,
#     "listingUrl": "https://www.domain.com.au/906-238-flinders-street-melbourne-vic-3000-14781843",
#     "unitNumber": "906",
#     "streetNumber": "238",
#     "street": "Flinders Street",
#     "suburb": "Melbourne",
#     "postcode": "3000",
#     "createdOn": "2020-12-20T20:35:58.89",
#     "propertyType": "Apartment / Unit / Flat",
#     "beds": 1,
#     "phone": "0433104343",
#     "agencyName": "Melbourne Residential Real Estate",
#     "propertyDeveloperName": "Melbourne Residential Real Estate",
#     "agencyProfileUrl": "https://www.domain.com.au/real-estate-agencies/melbourneresidentialrealestate-22398/",
#     "propertyDeveloperUrl": "https://www.domain.com.au/real-estate-agencies/melbourneresidentialrealestate-22398/",
#     "description": [
#       "This furnished large size studio has a lot to offer.",
#       "",
#       " Features include a fully equipped kitchen with gas cooking stove, new fridge, a good size open dining/ living area, wall to wall windows boast natural light, facing East towards Federation Square and St Paul's Cathedral.",
#       "",
#       " Facilities include: ",
#       "",
#       "A common room with table tennis table, couches and a large screen TV.",
#       "",
#       "A common study area.",
#       "",
#       "Coin operated communal laundry.",
#       "",
#       "Secure intercom entrance.",
#       "",
#       "Secure door for each level.",
#       "",
#       " UniLodge on Flinders is situated right across from Flinders Street Station. Walking distance to business and retail precincts, RMIT, The University of Melbourne, Victoria University, and other colleges - So Convenient.",
#       "",
#       " Surrounded by the famous eateries and cafes around, the stylish Degraves Street is just around the corner. ",
#       "",
#       "Take a walk to the busy shopping and dining precincts like Chinatown, Melbourne Central and the restaurants along the Yarra River. ",
#       "",
#       " The Free Tram Zone is right outside the doorstep, taking you to attractions all around Melbourne like Queen Victoria Market, historical gardens and more.",
#       "",
#       "Property Code: 555"
#     ],
#     "loanfinder": null,
#     "schools": [
#       {
#         "id": "",
#         "educationLevel": "combined",
#         "name": "Eltham College - Lonsdale Street Campus",
#         "distance": 754.5168213805954,
#         "state": "VIC",
#         "postCode": "3000",
#         "year": "",
#         "gender": "",
#         "type": "Private",
#         "address": "Melbourne, VIC 3000",
#         "url": "",
#         "domainSeoUrlSlug": "eltham-college-lonsdale-street-campus-vic-3000-46233"
#       },
#       {
#         "id": "",
#         "educationLevel": "secondary",
#         "name": "Stott's Colleges",
#         "distance": 759.4490361478412,
#         "state": "VIC",
#         "postCode": "3000",
#         "year": "11-12",
#         "gender": "",
#         "type": "Private",
#         "address": "Melbourne, VIC 3000",
#         "url": "https://www.stotts.edu.au/",
#         "domainSeoUrlSlug": "stotts-colleges-vic-3000-50313"
#       },
#       {
#         "id": "",
#         "educationLevel": "secondary",
#         "name": "Ozford College - Ozford College Campus",
#         "distance": 793.5396583051282,
#         "state": "VIC",
#         "postCode": "3000",
#         "year": "",
#         "gender": "",
#         "type": "Private",
#         "address": "Melbourne, VIC 3000",
#         "url": "",
#         "domainSeoUrlSlug": "ozford-college-english-language-centre-vic-3000-52094"
#       },
#       {
#         "id": "",
#         "educationLevel": "secondary",
#         "name": "Ozford College",
#         "distance": 794.762671640391,
#         "state": "VIC",
#         "postCode": "3000",
#         "year": "10-11",
#         "gender": "CoEd",
#         "type": "Private",
#         "address": "Melbourne, VIC 3000",
#         "url": "http://www.ozford.edu.au",
#         "domainSeoUrlSlug": "ozford-college-vic-3000-40714"
#       },
#       {
#         "id": "",
#         "educationLevel": "secondary",
#         "name": "Hester Hornbrook Academy - City Campus",
#         "distance": 870.0716585660363,
#         "state": "VIC",
#         "postCode": "3000",
#         "year": "",
#         "gender": "",
#         "type": "Private",
#         "address": "Melbourne, VIC 3000",
#         "url": "",
#         "domainSeoUrlSlug": "hester-hornbrook-academy-city-campus-vic-3000-52519"
#       },
#       {
#         "id": "",
#         "educationLevel": "combined",
#         "name": "Eltham College - King Street Campus",
#         "distance": 947.3222695015901,
#         "state": "VIC",
#         "postCode": "3000",
#         "year": "",
#         "gender": "",
#         "type": "Private",
#         "address": "Melbourne, VIC 3000",
#         "url": "",
#         "domainSeoUrlSlug": "eltham-college-king-street-campus-vic-3000-52625"
#       },
#       {
#         "id": "",
#         "educationLevel": "secondary",
#         "name": "Holmes Grammar School",
#         "distance": 949.0731084190468,
#         "state": "VIC",
#         "postCode": "3000",
#         "year": "11-12",
#         "gender": "",
#         "type": "Private",
#         "address": "Melbourne, VIC 3000",
#         "url": "https://www.holmes.edu.au/pages/schools-and-faculties/secondary",
#         "domainSeoUrlSlug": "holmes-secondary-college-vic-3000-40736"
#       },
#       {
#         "id": "",
#         "educationLevel": "secondary",
#         "name": "Hester Hornbrook Academy - South Melbourne",
#         "distance": 1324.1079305823796,
#         "state": "VIC",
#         "postCode": "3205",
#         "year": "",
#         "gender": "",
#         "type": "Private",
#         "address": "South Melbourne, VIC 3205",
#         "url": "",
#         "domainSeoUrlSlug": "hester-hornbrook-academy-south-melbourne-vic-3205-53254"
#       },
#       {
#         "id": "",
#         "educationLevel": "secondary",
#         "name": "Hester Hornbrook Academy",
#         "distance": 1330.4139619559455,
#         "state": "VIC",
#         "postCode": "3000",
#         "year": "10-12",
#         "gender": "CoEd",
#         "type": "Private",
#         "address": "Melbourne, VIC 3000",
#         "url": "https://www.melbournecitymission.org.au/services/.../hester-hornbrook-academy",
#         "domainSeoUrlSlug": "hester-hornbrook-academy-vic-3205-52517"
#       },
#       {
#         "id": "",
#         "educationLevel": "combined",
#         "name": "Haileybury College - City Girls",
#         "distance": 1378.7741189344376,
#         "state": "VIC",
#         "postCode": "3006",
#         "year": "",
#         "gender": "",
#         "type": "Private",
#         "address": "West Melbourne, VIC 3006",
#         "url": "",
#         "domainSeoUrlSlug": "haileybury-college-city-girls-vic-3006-53317"
#       },
#       {
#         "id": "1266",
#         "educationLevel": "primary",
#         "name": "Carlton Gardens Primary School",
#         "distance": 1737.4142599102372,
#         "state": "VIC",
#         "postCode": "3053",
#         "year": "Prep-6",
#         "gender": "CoEd",
#         "type": "Government",
#         "address": "Carlton, VIC 3053",
#         "url": "http://www.carltongardens.vic.edu.au",
#         "domainSeoUrlSlug": "carlton-gardens-primary-school-vic-3053-1266"
#       },
#       {
#         "id": "3946",
#         "educationLevel": "secondary",
#         "name": "University High School",
#         "distance": 2468.0774196931925,
#         "state": "VIC",
#         "postCode": "3052",
#         "year": "7-12",
#         "gender": "CoEd",
#         "type": "Government",
#         "address": "Parkville, VIC 3052",
#         "url": "http://www.unihigh.vic.edu.au",
#         "domainSeoUrlSlug": "university-high-school-vic-3052-3946"
#       }
#     ],
#     "suburbInsights": {
#       "beds": 1,
#       "propertyType": "Unit",
#       "suburb": "Melbourne",
#       "suburbProfileUrl": "/suburb-profile/melbourne-vic-3000",
#       "medianPrice": 375000,
#       "medianRentPrice": 525,
#       "avgDaysOnMarket": 110,
#       "auctionClearance": 50,
#       "nrSoldThisYear": 613,
#       "entryLevelPrice": 195000,
#       "luxuryLevelPrice": 659000,
#       "renterPercentage": 0.6970133677881032,
#       "singlePercentage": 0.7628455892048701,
#       "demographics": {
#         "population": 47279,
#         "avgAge": "20 to 39",
#         "owners": 0.3029866322118968,
#         "renters": 0.6970133677881032,
#         "families": 0.2371544107951299,
#         "singles": 0.7628455892048701,
#         "clarification": true
#       },
#       "salesGrowthList": [
#         {
#           "medianSoldPrice": 426000,
#           "annualGrowth": 0,
#           "numberSold": 676,
#           "year": "2019",
#           "daysOnMarket": 94
#         },
#         {
#           "medianSoldPrice": 400000,
#           "annualGrowth": -0.06103286384976526,
#           "numberSold": 532,
#           "year": "2020",
#           "daysOnMarket": 80
#         },
#         {
#           "medianSoldPrice": 355000,
#           "annualGrowth": -0.1125,
#           "numberSold": 320,
#           "year": "2021",
#           "daysOnMarket": 108
#         },
#         {
#           "medianSoldPrice": 331000,
#           "annualGrowth": -0.0676056338028169,
#           "numberSold": 421,
#           "year": "2022",
#           "daysOnMarket": 126
#         },
#         {
#           "medianSoldPrice": 345000,
#           "annualGrowth": 0.04229607250755287,
#           "numberSold": 547,
#           "year": "2023",
#           "daysOnMarket": 125
#         },
#         {
#           "medianSoldPrice": 375000,
#           "annualGrowth": 0.08695652173913043,
#           "numberSold": 613,
#           "year": "2024",
#           "daysOnMarket": 110
#         }
#       ],
#       "mostRecentSale": null
#     },
#     "gallery": {
#       "slides": [
#         {
#           "thumbnail": "https://rimh2.domainstatic.com.au/q58fcPQ6EsijYcCLFLjVOoGZ54s=/fit-in/144x106/filters:format(jpeg):quality(80):no_upscale()/2016603677_2_1_201105_094936-w1200-h800",
#           "images": {
#             "original": {
#               "url": "https://rimh2.domainstatic.com.au/vNdFWmuK6I9Qa2YFnPEEJYkIquU=/fit-in/1920x1080/filters:format(jpeg):quality(80):no_upscale()/2016603677_2_1_201105_094936-w1200-h800",
#               "width": 1200,
#               "height": 800
#             },
#             "tablet": {
#               "url": "https://rimh2.domainstatic.com.au/ZctbJ-cXOOmYEQnA4eIarY6bHVQ=/fit-in/1020x1020/filters:format(jpeg):quality(80):no_upscale()/2016603677_2_1_201105_094936-w1200-h800",
#               "width": 1020,
#               "height": 680
#             },
#             "mobile": {
#               "url": "https://rimh2.domainstatic.com.au/uZTwfrYEDJOVSjnmXtqUEAKBX_s=/fit-in/600x800/filters:format(jpeg):quality(80):no_upscale()/2016603677_2_1_201105_094936-w1200-h800",
#               "width": 600,
#               "height": 400
#             }
#           },
#           "embedUrl": null,
#           "mediaType": "image"
#         },
#         {
#           "thumbnail": "https://rimh2.domainstatic.com.au/_k-jZomymAeUJf_BcBl39OGKjKk=/fit-in/144x106/filters:format(jpeg):quality(80):no_upscale()/2016603677_3_1_201105_094936-w1200-h800",
#           "images": {
#             "original": {
#               "url": "https://rimh2.domainstatic.com.au/MsW8PgroAjpJoPx7hp29qVT6jTg=/fit-in/1920x1080/filters:format(jpeg):quality(80):no_upscale()/2016603677_3_1_201105_094936-w1200-h800",
#               "width": 1200,
#               "height": 800
#             },
#             "tablet": {
#               "url": "https://rimh2.domainstatic.com.au/Oj4mW8yaZhUPx6Mq2QBClRgpySc=/fit-in/1020x1020/filters:format(jpeg):quality(80):no_upscale()/2016603677_3_1_201105_094936-w1200-h800",
#               "width": 1020,
#               "height": 680
#             },
#             "mobile": {
#               "url": "https://rimh2.domainstatic.com.au/HJPPtFc6lb4bOFV8r4RUOA16G3M=/fit-in/600x800/filters:format(jpeg):quality(80):no_upscale()/2016603677_3_1_201105_094936-w1200-h800",
#               "width": 600,
#               "height": 400
#             }
#           },
#           "embedUrl": null,
#           "mediaType": "image"
#         },
#         {
#           "thumbnail": "https://rimh2.domainstatic.com.au/YLtojY7X7gpmuNKlTGx2wl4kACw=/fit-in/144x106/filters:format(jpeg):quality(80):no_upscale()/2016603677_4_1_201105_094936-w1200-h800",
#           "images": {
#             "original": {
#               "url": "https://rimh2.domainstatic.com.au/iV7vJWxk6d1uJ2pUqLsGcGQSaAg=/fit-in/1920x1080/filters:format(jpeg):quality(80):no_upscale()/2016603677_4_1_201105_094936-w1200-h800",
#               "width": 1200,
#               "height": 800
#             },
#             "tablet": {
#               "url": "https://rimh2.domainstatic.com.au/S1ciYHoc3oF5O9e0OgUz7qmHkVk=/fit-in/1020x1020/filters:format(jpeg):quality(80):no_upscale()/2016603677_4_1_201105_094936-w1200-h800",
#               "width": 1020,
#               "height": 680
#             },
#             "mobile": {
#               "url": "https://rimh2.domainstatic.com.au/hOEwBPn9WlP_sY0_wOLlnRBfops=/fit-in/600x800/filters:format(jpeg):quality(80):no_upscale()/2016603677_4_1_201105_094936-w1200-h800",
#               "width": 600,
#               "height": 400
#             }
#           },
#           "embedUrl": null,
#           "mediaType": "image"
#         },
#         {
#           "thumbnail": "https://rimh2.domainstatic.com.au/e1PGE8WG3QiWw1XC78Ap8YwVVtw=/fit-in/144x106/filters:format(jpeg):quality(80):no_upscale()/2016603677_5_1_201105_094936-w1200-h800",
#           "images": {
#             "original": {
#               "url": "https://rimh2.domainstatic.com.au/x4Ox9eGv0oWKrVBXxsElR8MuKNM=/fit-in/1920x1080/filters:format(jpeg):quality(80):no_upscale()/2016603677_5_1_201105_094936-w1200-h800",
#               "width": 1200,
#               "height": 800
#             },
#             "tablet": {
#               "url": "https://rimh2.domainstatic.com.au/pauvRxL2KRPxLP_BoDWQJFh0M_E=/fit-in/1020x1020/filters:format(jpeg):quality(80):no_upscale()/2016603677_5_1_201105_094936-w1200-h800",
#               "width": 1020,
#               "height": 680
#             },
#             "mobile": {
#               "url": "https://rimh2.domainstatic.com.au/W-l5ecoVjemy8CFrgP2wQeYmU4A=/fit-in/600x800/filters:format(jpeg):quality(80):no_upscale()/2016603677_5_1_201105_094936-w1200-h800",
#               "width": 600,
#               "height": 400
#             }
#           },
#           "embedUrl": null,
#           "mediaType": "image"
#         },
#         {
#           "thumbnail": "https://rimh2.domainstatic.com.au/tzjjhFcZYHi08X-l1JpIyXABTmc=/fit-in/144x106/filters:format(jpeg):quality(80):no_upscale()/2016603677_6_1_201105_094936-w1200-h800",
#           "images": {
#             "original": {
#               "url": "https://rimh2.domainstatic.com.au/oOvGblLfPJscib1lq_G2dhovdH4=/fit-in/1920x1080/filters:format(jpeg):quality(80):no_upscale()/2016603677_6_1_201105_094936-w1200-h800",
#               "width": 1200,
#               "height": 800
#             },
#             "tablet": {
#               "url": "https://rimh2.domainstatic.com.au/3pdN3aBvAgOgm44as6BMWW63hUU=/fit-in/1020x1020/filters:format(jpeg):quality(80):no_upscale()/2016603677_6_1_201105_094936-w1200-h800",
#               "width": 1020,
#               "height": 680
#             },
#             "mobile": {
#               "url": "https://rimh2.domainstatic.com.au/wt5pSMo7ZWiIIa97FgCFYRHUZQs=/fit-in/600x800/filters:format(jpeg):quality(80):no_upscale()/2016603677_6_1_201105_094936-w1200-h800",
#               "width": 600,
#               "height": 400
#             }
#           },
#           "embedUrl": null,
#           "mediaType": "image"
#         },
#         {
#           "thumbnail": "https://rimh2.domainstatic.com.au/zUykOC3VXNsE0oczzZh2aRuANT8=/fit-in/144x106/filters:format(jpeg):quality(80):no_upscale()/2016603677_7_1_201105_094936-w1200-h800",
#           "images": {
#             "original": {
#               "url": "https://rimh2.domainstatic.com.au/uHuP04tCJxddc2U_ABcg5LDk8KQ=/fit-in/1920x1080/filters:format(jpeg):quality(80):no_upscale()/2016603677_7_1_201105_094936-w1200-h800",
#               "width": 1200,
#               "height": 800
#             },
#             "tablet": {
#               "url": "https://rimh2.domainstatic.com.au/Be7cueViofr0lucxPUqHi8SbTP8=/fit-in/1020x1020/filters:format(jpeg):quality(80):no_upscale()/2016603677_7_1_201105_094936-w1200-h800",
#               "width": 1020,
#               "height": 680
#             },
#             "mobile": {
#               "url": "https://rimh2.domainstatic.com.au/FlQ70_E1IhXnBU0Z8D-8c_XBRU0=/fit-in/600x800/filters:format(jpeg):quality(80):no_upscale()/2016603677_7_1_201105_094936-w1200-h800",
#               "width": 600,
#               "height": 400
#             }
#           },
#           "embedUrl": null,
#           "mediaType": "image"
#         },
#         {
#           "thumbnail": "https://rimh2.domainstatic.com.au/kQ0wnqO3_3_phUUmrTMh8XN-oc0=/fit-in/144x106/filters:format(jpeg):quality(80):no_upscale()/2016603677_7_1_201122_110110-w1200-h800",
#           "images": {
#             "original": {
#               "url": "https://rimh2.domainstatic.com.au/tqQTtEODXZhDC_Ik0ujRT49mjtU=/fit-in/1920x1080/filters:format(jpeg):quality(80):no_upscale()/2016603677_7_1_201122_110110-w1200-h800",
#               "width": 1200,
#               "height": 800
#             },
#             "tablet": {
#               "url": "https://rimh2.domainstatic.com.au/2x2ZL8nITSwjyTSWbGS_kY45DJA=/fit-in/1020x1020/filters:format(jpeg):quality(80):no_upscale()/2016603677_7_1_201122_110110-w1200-h800",
#               "width": 1020,
#               "height": 680
#             },
#             "mobile": {
#               "url": "https://rimh2.domainstatic.com.au/7ybFsR3rlUOh8dmPXsXRQP-Jzl4=/fit-in/600x800/filters:format(jpeg):quality(80):no_upscale()/2016603677_7_1_201122_110110-w1200-h800",
#               "width": 600,
#               "height": 400
#             }
#           },
#           "embedUrl": null,
#           "mediaType": "image"
#         },
#         {
#           "thumbnail": "https://rimh2.domainstatic.com.au/esokrCph-reikzOVSdtZZbypw_4=/fit-in/144x106/filters:format(jpeg):quality(80):no_upscale()/2016603677_8_3_201122_110110-w1944-h1598",
#           "images": {
#             "original": {
#               "url": "https://rimh2.domainstatic.com.au/VwjoQeqM20CAcmI5aRtj0ZFqJRw=/fit-in/1920x1080/filters:format(jpeg):quality(80):no_upscale()/2016603677_8_3_201122_110110-w1944-h1598",
#               "width": 1314,
#               "height": 1080
#             },
#             "tablet": {
#               "url": "https://rimh2.domainstatic.com.au/vLKEnTkBjXZVHZd1DNICRQd-S1M=/fit-in/1020x1020/filters:format(jpeg):quality(80):no_upscale()/2016603677_8_3_201122_110110-w1944-h1598",
#               "width": 1020,
#               "height": 838
#             },
#             "mobile": {
#               "url": "https://rimh2.domainstatic.com.au/XnmIY-8nHi3rQn3f8XWYQYzlvTI=/fit-in/600x800/filters:format(jpeg):quality(80):no_upscale()/2016603677_8_3_201122_110110-w1944-h1598",
#               "width": 600,
#               "height": 493
#             }
#           },
#           "embedUrl": null,
#           "mediaType": "floorplan"
#         }
#       ]
#     },
#     "listingSummary": {
#       "address": "906/238 Flinders Street, Melbourne VIC 3000",
#       "baths": 1,
#       "beds": 1,
#       "houses": 0,
#       "isRural": false,
#       "listingType": "rent",
#       "mode": "rent",
#       "parking": 0,
#       "promoType": "platinum",
#       "propertyType": "Apartment / Unit / Flat",
#       "showDefaultFeatures": true,
#       "showDomainInsight": false,
#       "stats": [
#         {
#           "key": "availableFrom",
#           "value": "Saturday, 28th September 2024",
#           "iso8601Value": "2024-09-28T00:00:00"
#         },
#         {
#           "key": "bond",
#           "value": 1738
#         }
#       ],
#       "status": "recentlyUpdated",
#       "title": "$400 per week"
#     },
#     "agents": [
#       {
#         "name": "Wimpie Santoso",
#         "photo": null,
#         "phone": "0422017406",
#         "mobile": "",
#         "agentProfileUrl": "https://www.domain.com.au/real-estate-agent/wimpie-santoso-1759352",
#         "email": "d2ltcGllQG1lbGJyZXNpZGVudGlhbC5jb20uYXU="
#       }
#     ],
#     "features": [],
#     "structuredFeatures": [],
#     "faqs": [
#       {
#         "question": "What is the weekly rent for 906/238 Flinders Street, Melbourne?",
#         "answer": [
#           {
#             "text": "The weekly rent for 906/238 Flinders Street, Melbourne is $400 per week."
#           }
#         ]
#       },
#       {
#         "question": "When is 906/238 Flinders Street, Melbourne available to rent?",
#         "answer": [
#           {
#             "text": "906/238 Flinders Street, Melbourne is available to rent from Saturday 28th September, 2024."
#           }
#         ]
#       },
#       {
#         "question": "How much is the rental bond for 906/238 Flinders Street, Melbourne?",
#         "answer": [
#           {
#             "text": "The bond for 906/238 Flinders Street, Melbourne is $1738."
#           }
#         ]
#       },
#       {
#         "question": "How many bedrooms does 906/238 Flinders Street, Melbourne have?",
#         "answer": [
#           {
#             "text": "906/238 Flinders Street, Melbourne is a 1 bedroom apartment."
#           }
#         ]
#       },
#       {
#         "question": "What are the key property features of 906/238 Flinders Street, Melbourne?",
#         "answer": [
#           {
#             "text": "To enquire about specific property features for 906/238 Flinders Street, Melbourne, "
#           },
#           {
#             "text": "contact the agent.",
#             "scrollTo": "enquiry-form"
#           }
#         ]
#       },
#       {
#         "question": "What is the size of the property at 906/238 Flinders Street, Melbourne?",
#         "answer": [
#           {
#             "text": "The property size for 906/238 Flinders Street, Melbourne has not been disclosed. To find detailed information on property size, "
#           },
#           {
#             "text": "contact the agent.",
#             "scrollTo": "enquiry-form"
#           }
#         ]
#       },
#       {
#         "question": "How many car spaces does 906/238 Flinders Street, Melbourne have?",
#         "answer": [
#           {
#             "text": "There were no car spaces found on the listing for 906/238 Flinders Street, Melbourne."
#           }
#         ]
#       }
#     ]
#   }
# ]
