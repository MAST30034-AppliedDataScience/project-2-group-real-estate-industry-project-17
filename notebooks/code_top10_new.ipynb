# %%
import pandas as pd

combine_df = pd.read_csv('../data/curated/combine_all.csv')

# %%
combine_df.columns
# Out:
# Index(['id', 'promoType', 'price', 'hasVideo', 'agentNames', 'brandName',
#        'addressStreet', 'addressSuburb', 'addressState', 'addressPostcode',
#        'addressLat', 'addressLng', 'num_bath', 'type', 'formatted', 'isRural',
#        'landSize', 'Retirement', 'postcode', '2023_population',
#        'ERP_2023_change_number', 'natural_2023_increase_number',
#        'internal_2023_migration_number', 'overseas_2023_migration_number',
#        'area_in_square_kilometers', 'estimated_2024_population', 'IEO_Score',
#        'IEO_State Rank', 'IEO_State Decile', 'IEO_State Percentile',
#        'IER_Usual Resident Population', 'IER_Score', 'IER_State Rank',
#        'IER_State Decile', 'IER_State Percentile',
#        'ERP_2023_change_percentage(%)', 'population_density_2023',
#        'nearest_station', 'min_walking_distance_to_station',
#        'min_distance_to_university', 'min_distance_to_shopping_mall',
#        'min_distance_to_secondary_school', 'min_distance_to_primary_school',
#        'min_distance_to_park', 'medical_institution_count'],
#       dtype='object')

# %%
df = combine_df.copy()

# Calculate the growth rate
df['2023_growth_rate'] = df['natural_2023_increase_number'] / df['2023_population'] * 100


# Calculate the growth rate
df['2024_growth_rate'] = (df['estimated_2024_population'] - df['2023_population']) / df['2023_population'] * 100

# Assuming df is your DataFrame and you've already calculated 2024_growth_rate

# Step 1: Calculate the growth factor (1 + growth_rate/100)
df['2025_growth_factor'] = 1.12 + (df['2024_growth_rate'] / 100)

# Step 2: Estimate population for 2025 and 2026
df['estimated_2025_population'] = df['estimated_2024_population'] * df['2025_growth_factor']


# Step 3: Calculate growth rates for 2025 and 2026
df['2025_growth_rate'] = (df['estimated_2025_population'] - df['estimated_2024_population']) / df['estimated_2024_population'] * 100

df['2026_growth_factor'] = 0.87 + (df['2025_growth_rate'] / 100)
df['estimated_2026_population'] = df['estimated_2025_population'] * df['2026_growth_factor']
df['2026_growth_rate'] = (df['estimated_2026_population'] - df['estimated_2025_population']) / df['estimated_2025_population'] * 100


# Select only the relevant columns
result_df=df[['addressSuburb', '2023_population', 
              'estimated_2024_population', '2024_growth_rate',
              '2025_growth_rate', '2026_growth_rate']]


result = result_df.groupby('addressSuburb').mean().sort_values('2024_growth_rate', ascending=False).head(10)

result
# Out:
#                 2023_population  estimated_2024_population  2024_growth_rate  \
# addressSuburb
# CARLTON            21376.000000               25309.000000         18.399139
# MELBOURNE          39819.516949               45509.381356         12.532195
# MANOR LAKES        80341.000000               90071.000000         12.110877
# WYNDHAM VALE       80341.000000               90071.000000         12.110877
# WEST MELBOURNE      8724.000000                9483.000000          8.700138
# FOOTSCRAY          29532.000000               31749.000000          7.507111
# DOCKLANDS          17723.000000               19052.000000          7.498730
# BOX HILL           25286.000000               26828.000000          6.098236
# BRUNSWICK          14057.000000               14900.000000          5.997012
# RICHMOND           33568.000000               35290.000000          5.129886
#
#                 2025_growth_rate  2026_growth_rate
# addressSuburb
# CARLTON                30.399139         17.399139
# MELBOURNE              24.532195         11.532195
# MANOR LAKES            24.110877         11.110877
# WYNDHAM VALE           24.110877         11.110877
# WEST MELBOURNE         20.700138          7.700138
# FOOTSCRAY              19.507111          6.507111
# DOCKLANDS              19.498730          6.498730
# BOX HILL               18.098236          5.098236
# BRUNSWICK              17.997012          4.997012
# RICHMOND               17.129886          4.129886

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# 2. Correlation analysis
correlation_columns = ['2024_growth_rate', 'IEO_Score', 'IER_Score', 'population_density_2023', 
                    'min_distance_to_university', 
                       'min_distance_to_shopping_mall', 'min_distance_to_secondary_school', 
                       'min_distance_to_primary_school', 'min_distance_to_park']

correlation_matrix = df[correlation_columns].corr()

# 3. Growth rate distribution
plt.figure(figsize=(12, 6))
sns.histplot(df['2024_growth_rate'], kde=True)
plt.title('Distribution of Growth Rates')
plt.xlabel('Growth Rate (%)')
plt.ylabel('Frequency')
plt.show()

# 4. Scatter plot: Growth Rate vs. IEO Score
plt.figure(figsize=(10, 6))
sns.scatterplot(x='IEO_Score', y='2024_growth_rate', data=df)
plt.title('Growth Rate vs. IEO Score')
plt.xlabel('IEO Score')
plt.ylabel('Growth Rate (%)')
plt.show()

# 5. Box plot: Growth Rate by IER State Decile
plt.figure(figsize=(12, 6))
sns.boxplot(x='IER_State Decile', y='2024_growth_rate', data=df)
plt.title('Growth Rate Distribution by IER State Decile')
plt.xlabel('IER State Decile')
plt.ylabel('Growth Rate (%)')
plt.show()

# 6. Regression analysis: Growth Rate vs. Population Density
slope, intercept, r_value, p_value, std_err = stats.linregress(df['population_density_2023'], df['2024_growth_rate'])

plt.figure(figsize=(10, 6))
sns.regplot(x='population_density_2023', y='2024_growth_rate', data=df, scatter_kws={'alpha':0.5})
plt.title(f'Growth Rate vs. Population Density (R² = {r_value**2:.4f})')
plt.xlabel('Population Density (2023)')
plt.ylabel('Growth Rate (%)')
plt.show()

print("\nCorrelation Matrix:")
print(correlation_matrix)

print(f"\nRegression Analysis - Growth Rate vs. Population Density:")
print(f"R-squared: {r_value**2:.4f}")
print(f"p-value: {p_value:.4f}")
print(f"Slope: {slope:.4f}")
print(f"Intercept: {intercept:.4f}")
# Out:
# Correlation Matrix:
#                                   2024_growth_rate  IEO_Score  IER_Score  \
# 2024_growth_rate                          1.000000   0.107619  -0.806300
# IEO_Score                                 0.107619   1.000000  -0.486640
# IER_Score                                -0.806300  -0.486640   1.000000
# population_density_2023                   0.763107   0.381360  -0.863381
# min_distance_to_university               -0.038317  -0.585461   0.298414
# min_distance_to_shopping_mall            -0.072361  -0.824946   0.453865
# min_distance_to_secondary_school         -0.076963  -0.561249   0.320599
# min_distance_to_primary_school           -0.042944  -0.454321   0.242759
# min_distance_to_park                      0.006172  -0.352711   0.148311
#
#                                   population_density_2023  \
# 2024_growth_rate                                 0.763107
# IEO_Score                                        0.381360
# IER_Score                                       -0.863381
# population_density_2023                          1.000000
# min_distance_to_university                      -0.151988
# min_distance_to_shopping_mall                   -0.293287
# min_distance_to_secondary_school                -0.234274
# min_distance_to_primary_school                  -0.153243
# min_distance_to_park                            -0.048689
#
#                                   min_distance_to_university  \
# 2024_growth_rate                                   -0.038317
# IEO_Score                                          -0.585461
# IER_Score                                           0.298414
# population_density_2023                            -0.151988
# min_distance_to_university                          1.000000
# min_distance_to_shopping_mall                       0.639393
# min_distance_to_secondary_school                    0.675502
# min_distance_to_primary_school                      0.495013
# min_distance_to_park                                0.496203
#
#                                   min_distance_to_shopping_mall  \
# 2024_growth_rate                                      -0.072361
# IEO_Score                                             -0.824946
# IER_Score                                              0.453865
# population_density_2023                               -0.293287
# min_distance_to_university                             0.639393
# min_distance_to_shopping_mall                          1.000000
# min_distance_to_secondary_school                       0.658471
# min_distance_to_primary_school                         0.393843
# min_distance_to_park                                   0.281272
#
#                                   min_distance_to_secondary_school  \
# 2024_growth_rate                                         -0.076963
# IEO_Score                                                -0.561249
# IER_Score                                                 0.320599
# population_density_2023                                  -0.234274
# min_distance_to_university                                0.675502
# min_distance_to_shopping_mall                             0.658471
# min_distance_to_secondary_school                          1.000000
# min_distance_to_primary_school                            0.594130
# min_distance_to_park                                      0.429561
#
#                                   min_distance_to_primary_school  \
# 2024_growth_rate                                       -0.042944
# IEO_Score                                              -0.454321
# IER_Score                                               0.242759
# population_density_2023                                -0.153243
# min_distance_to_university                              0.495013
# min_distance_to_shopping_mall                           0.393843
# min_distance_to_secondary_school                        0.594130
# min_distance_to_primary_school                          1.000000
# min_distance_to_park                                    0.573360
#
#                                   min_distance_to_park
# 2024_growth_rate                              0.006172
# IEO_Score                                    -0.352711
# IER_Score                                     0.148311
# population_density_2023                      -0.048689
# min_distance_to_university                    0.496203
# min_distance_to_shopping_mall                 0.281272
# min_distance_to_secondary_school              0.429561
# min_distance_to_primary_school                0.573360
# min_distance_to_park                          1.000000
#
# Regression Analysis - Growth Rate vs. Population Density:
# R-squared: 0.5823
# p-value: 0.0000
# Slope: 0.0005
# Intercept: 3.9268

# %%
df = df.drop(columns=['agentNames', 'brandName', 'addressStreet', 
                              'addressSuburb', 'addressState',
                              'id'])

# 2025_growth_rate	2026_growth_rate

# %%
numeric_features = df.select_dtypes(exclude=['object']).columns.to_list()
numeric_features
# Out:
# ['price',
#  'hasVideo',
#  'addressPostcode',
#  'addressLat',
#  'addressLng',
#  'num_bath',
#  'isRural',
#  'landSize',
#  'Retirement',
#  'postcode',
#  '2023_population',
#  'ERP_2023_change_number',
#  'natural_2023_increase_number',
#  'internal_2023_migration_number',
#  'overseas_2023_migration_number',
#  'area_in_square_kilometers',
#  'estimated_2024_population',
#  'IEO_Score',
#  'IEO_State Rank',
#  'IEO_State Decile',
#  'IEO_State Percentile',
#  'IER_Usual Resident Population',
#  'IER_Score',
#  'IER_State Rank',
#  'IER_State Decile',
#  'IER_State Percentile',
#  'ERP_2023_change_percentage(%)',
#  'population_density_2023',
#  'min_walking_distance_to_station',
#  'min_distance_to_university',
#  'min_distance_to_shopping_mall',
#  'min_distance_to_secondary_school',
#  'min_distance_to_primary_school',
#  'min_distance_to_park',
#  'medical_institution_count',
#  '2023_growth_rate',
#  '2024_growth_rate',
#  '2025_growth_factor',
#  'estimated_2025_population',
#  '2025_growth_rate',
#  '2026_growth_factor',
#  'estimated_2026_population',
#  '2026_growth_rate']

# %%
features = ['num_bath', 'IEO_Score', 'addressLat', 'addressLng',
       'area_in_square_kilometers', 'min_distance_to_park',
       'min_distance_to_primary_school',
       'min_distance_to_secondary_school', '2024_growth_rate',
       ]

target = 'price'
df = df.dropna()
data_2024 = df[features+[target]]
data_2024 = data_2024.rename(columns={'2024_growth_rate' : 'growth_rate'})

# %%
# import the random forest regressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor

# instantiate model with 200 decision trees
rf = RandomForestRegressor(random_state=42)

gb = GradientBoostingRegressor(random_state=42)

# %%
train_features = ['num_bath', 'IEO_Score', 'addressLat', 'addressLng',
                  'area_in_square_kilometers', 'min_distance_to_park',
       'min_distance_to_primary_school',
       'min_distance_to_secondary_school', 'growth_rate']
x_train = data_2024[train_features]
y_train = data_2024[target]


# split the data into two groups that are training set and the testing set
x_train_split, x_test_split, y_train_split, y_test_split = train_test_split(x_train, y_train, 
                                                                            test_size=0.3, shuffle=True)

# %%
# train the model on training data
rf.fit(x_train_split, y_train_split)
rf.score(x_test_split, y_test_split)# calculate the r squared
# Out:
# 0.5307137630940346

# %%
# train the model on training data
gb.fit(x_train_split, y_train_split)
gb.score(x_test_split, y_test_split)# calculate the r squared
# Out:
# 0.47301854925319886

# %%
features = ['num_bath', 'IEO_Score', 'addressLat', 'addressLng',
            'area_in_square_kilometers', 'min_distance_to_park',
       'min_distance_to_primary_school',
       'min_distance_to_secondary_school', '2025_growth_rate',
       ]
data_2025 = df[features+[target]]
data_2025 = data_2025.rename(columns={'2025_growth_rate' : 'growth_rate'})

predict_features = ['num_bath', 'IEO_Score', 'addressLat', 'addressLng',
                    'area_in_square_kilometers', 'min_distance_to_park',
       'min_distance_to_primary_school',
       'min_distance_to_secondary_school', 'growth_rate',
       ]
predict_2025 = data_2025[predict_features]


features = ['num_bath', 'IEO_Score', 'addressLat', 'addressLng',
            'area_in_square_kilometers', 'min_distance_to_park',
       'min_distance_to_primary_school',
       'min_distance_to_secondary_school', '2026_growth_rate',
       ]
data_2026 = df[features+[target]]
data_2026 = data_2026.rename(columns={'2026_growth_rate' : 'growth_rate'})
predict_2026 = data_2026[predict_features]

# %%
df['Pred_2024'] = rf.predict(x_train)
df['Pred_2025'] = rf.predict(predict_2025)
df['Pred_2026'] = rf.predict(predict_2026)

# %%
df
# Out:
#         promoType  price  hasVideo  addressPostcode  addressLat  addressLng  \
# 0     premiumplus  500.0     False             3003  -37.810738   144.95226
# 1     premiumplus  540.0      True             3003  -37.810135   144.95040
# 2      standardpp  650.0     False             3003  -37.810757   144.95224
# 3     premiumplus  560.0     False             3003  -37.810860   144.95183
# 4      standardpp  600.0     False             3003  -37.807606   144.94562
# ...           ...    ...       ...              ...         ...         ...
# 4268     standard  500.0     False             3024  -37.863820   144.58377
# 4269     standard  500.0     False             3024  -37.860850   144.59560
# 4270        elite  510.0     False             3024  -37.852295   144.59398
# 4271        elite  520.0     False             3024  -37.873215   144.60631
# 4272        elite  600.0     False             3024  -37.878292   144.59297
#
#       num_bath               type                formatted  isRural  ...  \
# 0          1.0  ApartmentUnitFlat  Apartment / Unit / Flat    False  ...
# 1          1.0  ApartmentUnitFlat  Apartment / Unit / Flat    False  ...
# 2          2.0  ApartmentUnitFlat  Apartment / Unit / Flat    False  ...
# 3          1.0  ApartmentUnitFlat  Apartment / Unit / Flat    False  ...
# 4          1.0  ApartmentUnitFlat  Apartment / Unit / Flat    False  ...
# ...        ...                ...                      ...      ...  ...
# 4268       2.0              House                    House    False  ...
# 4269       2.0              House                    House    False  ...
# 4270       2.0              House                    House    False  ...
# 4271       2.0              House                    House    False  ...
# 4272       2.0              House                    House    False  ...
#
#       2024_growth_rate  2025_growth_factor  estimated_2025_population  \
# 0             8.700138            1.207001               11445.994044
# 1             8.700138            1.207001               11445.994044
# 2             8.700138            1.207001               11445.994044
# 3             8.700138            1.207001               11445.994044
# 4             8.700138            1.207001               11445.994044
# ...                ...                 ...                        ...
# 4268         12.110877            1.241109              111787.908370
# 4269         12.110877            1.241109              111787.908370
# 4270         12.110877            1.241109              111787.908370
# 4271         12.110877            1.241109              111787.908370
# 4272         12.110877            1.241109              111787.908370
#
#       2025_growth_rate  2026_growth_factor  estimated_2026_population  \
# 0            20.700138            1.077001                12327.35133
# 1            20.700138            1.077001                12327.35133
# 2            20.700138            1.077001                12327.35133
# 3            20.700138            1.077001                12327.35133
# 4            20.700138            1.077001                12327.35133
# ...                ...                 ...                        ...
# 4268         24.110877            1.111109               124208.52580
# 4269         24.110877            1.111109               124208.52580
# 4270         24.110877            1.111109               124208.52580
# 4271         24.110877            1.111109               124208.52580
# 4272         24.110877            1.111109               124208.52580
#
#       2026_growth_rate   Pred_2024  Pred_2025  Pred_2026
# 0             7.700138  515.056667     450.15    517.490
# 1             7.700138  585.605000     399.43    585.555
# 2             7.700138  700.520000     569.35    706.820
# 3             7.700138  530.910000     446.25    532.810
# 4             7.700138  623.940000     419.97    624.240
# ...                ...         ...        ...        ...
# 4268         11.110877  504.900000     504.90    504.900
# 4269         11.110877  500.200000     500.20    500.200
# 4270         11.110877  506.750000     506.75    506.750
# 4271         11.110877  508.950000     508.95    508.950
# 4272         11.110877  551.100000     551.10    551.100
#
# [4259 rows x 50 columns]
